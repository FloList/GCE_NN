# %% [markdown]
# ## Tutorial notebook

# %% [markdown]
# This Jupyter notebook shows how to perform a basic analysis of γ-ray photon-count maps using the convolutional neural network-based method presented in [arXiv:2107.09070](http://arxiv.org/abs/2107.09070).
#
# In this example, the photon-count maps consist of **three** different emission components:
# 1. *Fermi* bubbles (Poissonian)
# 2. Galactic Center Excess (point source-like, single population)
# 3. Isotropic point sources (point source-like, two populations in each map).
#
# As discussed in the paper, for the point source-like templates the Poissonian case is included as the limit of ultra-faint point source emission (<< 1 photon expected per source) where the neural network can no longer distinguish point sources from Poissonian emission.
#
# To consider different scenarios (e.g. other templates, more training data, different network architectures, etc.), simply modify the sample parameter file ```GCE_NN/parameter_files/parameters.py``` accordingly.
# The available templates can be viewed in the function ```get_templates()``` in ```GCE/data_utils.py```.
#
# Also, if you don't have access to a GPU and just want to try out the code, it is recommended to reduce the number of training steps in the ```parameters.py```
# file in the folder ```parameter_files``` under "Training settings" from ```2500``` to e.g. ```p_train['num_steps'] = 500``` to reduce the
# training time. In this case, you will see a warning
# ```
# "WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`...
# ```

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import healpy as hp
import os

# %%
# %pip list | grep gce-nn   # check if gce-nn module is there
import GCE.gce
# Out:
# gce-nn                  0.0.1
# Note: you may need to restart the kernel to use updated packages.
# 2021-11-18 14:29:53.333971: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# /home/flo/.pyenv/versions/3.8.0/envs/venv_gce_nn_38/lib/python3.8/site-packages/redis/connection.py:72: UserWarning: redis-py works best with hiredis. Please consider installing
#   warnings.warn(msg)

# %% [markdown]
# First, we need to **initialize** an analysis object.

# %%
gce = GCE.gce.Analysis()
# Out:
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of devices: 1
# 2021-11-18 14:29:55.831215: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-18 14:29:55.832729: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-11-18 14:29:55.884619: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:55.885307: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3060 Laptop GPU computeCapability: 8.6
# coreClock: 1.282GHz coreCount: 30 deviceMemorySize: 5.81GiB deviceMemoryBandwidth: 268.26GiB/s
# 2021-11-18 14:29:55.885395: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-11-18 14:29:55.887363: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-11-18 14:29:55.887478: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-11-18 14:29:55.888116: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-11-18 14:29:55.888528: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-11-18 14:29:55.888980: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2021-11-18 14:29:55.889663: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-11-18 14:29:55.890540: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-11-18 14:29:55.890698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:55.890999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:55.891202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-11-18 14:29:55.891258: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-11-18 14:29:56.323892: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-11-18 14:29:56.323924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-11-18 14:29:56.323930: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-11-18 14:29:56.324160: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.324614: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.324991: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.325211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:0 with 2033 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6)
# 2021-11-18 14:29:56.326825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.327098: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3060 Laptop GPU computeCapability: 8.6
# coreClock: 1.282GHz coreCount: 30 deviceMemorySize: 5.81GiB deviceMemoryBandwidth: 268.26GiB/s
# 2021-11-18 14:29:56.327207: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.327434: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.327632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-11-18 14:29:56.327929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.328130: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3060 Laptop GPU computeCapability: 8.6
# coreClock: 1.282GHz coreCount: 30 deviceMemorySize: 5.81GiB deviceMemoryBandwidth: 268.26GiB/s
# 2021-11-18 14:29:56.328179: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.328667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.328926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-11-18 14:29:56.328960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-11-18 14:29:56.328966: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-11-18 14:29:56.328971: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-11-18 14:29:56.329134: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.329365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-18 14:29:56.329606: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 2033 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6)

# %% [markdown]
# Now, let's **load the parameters** from the parameter file in the parameter_files folder.

# %%
gce.load_params("../parameter_files/parameters.py")
# Out:
# Loading parameters from '../parameter_files/parameters.py'...
# Loading parameters: ['comb' 'data' 'gen' 'mod' 'nn' 'plot' 'train' 'tt']
# /home/flo/Documents/Projects/GCE_hist/GCE_NN/GCE/gce.py:272: RuntimeWarning: invalid value encountered in log10
#   bin_edges_mapped = np.log10(bin_edges) if self.p.nn.hist["log_spaced_bins"] else bin_edges

# %% [markdown]
# We can take a look at the loaded parameters:

# %%
gce.print_params()
# Out:
# {'comb': {'N_test': 2,
#           'N_val': 2,
#           'bins_counts_per_PS': array([-0.5,  2.5,  5.5,  8.5, 11.5, 14.5, 17.5, 20.5, 23.5, 26.5, 29.5,
#        32.5, 35.5, 38.5, 41.5, 44.5, 47.5, 50.5, 53.5, 56.5, 59.5,  inf]),
#           'bins_counts_per_pix': array([-0.5,  2.5,  5.5,  8.5, 11.5, 14.5, 17.5, 20.5, 23.5, 26.5, 29.5,
#        32.5, 35.5, 38.5, 41.5, 44.5, 47.5, 50.5, 53.5, 56.5, 59.5,  inf]),
#           'bins_dNdF': array([          -inf, 3.16227766e-13, 5.95662144e-13, 1.12201845e-12,
#        2.11348904e-12, 3.98107171e-12, 7.49894209e-12, 1.41253754e-11,
#        2.66072506e-11, 5.01187234e-11, 9.44060876e-11, 1.77827941e-10,
#        3.34965439e-10, 6.30957344e-10, 1.18850223e-09, 2.23872114e-09,
#        4.21696503e-09, 7.94328235e-09, 1.49623566e-08, 2.81838293e-08,
#        5.30884444e-08, 1.00000000e-07,            inf]),
#           'combine_without_PSF': False,
#           'data_name': 'Example_comb',
#           'do_counts_per_PS': False,
#           'do_counts_per_pix': False,
#           'do_dNdF': True,
#           'filename_base': 'Maps',
#           'hist_templates': ['gce_12_PS', 'iso_PS'],
#           'power_of_F_dNdF': 1},
#  'data': {'exposure': 'Fermi',
#           'inner_band': 2.0,
#           'leakage_delta': 0.75,
#           'mask_type': '3FGL',
#           'npix': 196608,
#           'nside': 128,
#           'outer_rad': 25.0,
#           'psf': True},
#  'gen': {'checkpoints_root': '../models/checkpoints',
#          'combined_maps_folder': '../data/Combined_maps/Example_comb_128',
#          'combined_maps_root': '../data/Combined_maps',
#          'data_root': '../data',
#          'fermi_folder': '../data/fermi_data_573w/fermi_data_128',
#          'fermi_root': '../data/fermi_data_573w',
#          'figures_root': '../models/figures',
#          'models_root': '../models',
#          'params_root': '../models/parameters',
#          'summaries_root': '../models/summaries',
#          'template_maps_folder': '../data/Template_maps/Example_128',
#          'template_maps_root': '../data/Template_maps'},
#  'mod': {'model_names': ['$\\it{Fermi}$ bubbles', 'GCE', 'isotropic PS'],
#          'model_names_P': ['$\\it{Fermi}$ bubbles'],
#          'model_names_PS': ['GCE', 'isotropic PS'],
#          'models': ['bub', 'gce_12_PS', 'iso_PS'],
#          'models_P': ['bub'],
#          'models_PS': ['gce_12_PS', 'iso_PS'],
#          'n_models': 3,
#          'n_models_P': 1,
#          'n_models_PS': 2},
#  'nn': {'NN_type': 'CNN',
#         'arch': {'F': [32, 64, 128, 256, 256, 256, 256],
#                  'K': [5, 5, 5, 5, 5, 5, 5],
#                  'M': [2048, 512],
#                  'activation': 'relu',
#                  'append_tot_counts': True,
#                  'batch_norm': [1, 1, 1, 1, 1, 1, 1, 0, 0],
#                  'conv': 'chebyshev5',
#                  'is_resnet': [False, False, False, False, False, False, False],
#                  'nsides': [128, 64, 32, 16, 8, 4, 2, 1],
#                  'pool': 'max'},
#         'checkpoints_folder': '../models/checkpoints/Example_comb_128/Training_1',
#         'checkpoints_folder_ff': '../models/checkpoints/Example_comb_128/Training_1/ff',
#         'checkpoints_folder_hist': '../models/checkpoints/Example_comb_128/Training_1/hist',
#         'cond': {'cond_on_training_data': <function <lambda> at 0x7f07bc0e1940>,
#                  'cond_on_training_data_str': 'lambda x: x.sum() > 0',
#                  'cond_on_training_labels': None,
#                  'cond_on_training_labels_str': None,
#                  'prob_for_conditions': 1.0},
#         'ff': {'alea_covar': False,
#                'alea_var': True,
#                'last_act': 'softmax',
#                'output_keys': ['ff_mean', 'ff_logvar'],
#                'rel_counts': True,
#                'return_ff': True},
#         'figures_folder': '../models/figures/Example_comb_128/Training_1',
#         'hist': {'calculate_residual': True,
#                  'hist_template_inds': array([1, 2]),
#                  'hist_template_names': ['GCE', 'isotropic PS'],
#                  'hist_templates': ['gce_12_PS', 'iso_PS'],
#                  'last_act': 'normalized_softplus',
#                  'log_spaced_bins': True,
#                  'n_bins': 22,
#                  'nn_hist_bins': array([          -inf, 3.16227766e-13, 5.95662144e-13, 1.12201845e-12,
#        2.11348904e-12, 3.98107171e-12, 7.49894209e-12, 1.41253754e-11,
#        2.66072506e-11, 5.01187234e-11, 9.44060876e-11, 1.77827941e-10,
#        3.34965439e-10, 6.30957344e-10, 1.18850223e-09, 2.23872114e-09,
#        4.21696503e-09, 7.94328235e-09, 1.49623566e-08, 2.81838293e-08,
#        5.30884444e-08, 1.00000000e-07,            inf]),
#                  'nn_hist_centers': array([2.30409298e-13, 4.34010264e-13, 8.17523038e-13, 1.53992653e-12,
#        2.90068120e-12, 5.46386550e-12, 1.02920053e-11, 1.93865264e-11,
#        3.65174127e-11, 6.87859912e-11, 1.29568670e-10, 2.44061907e-10,
#        4.59726989e-10, 8.65964323e-10, 1.63117291e-09, 3.07255737e-09,
#        5.78761988e-09, 1.09018449e-08, 2.05352503e-08, 3.86812055e-08,
#        7.28618175e-08, 1.37246096e-07]),
#                  'nn_hist_widths': array([1.48347364e-13, 2.79434378e-13, 5.26356311e-13, 9.91470586e-13,
#        1.86758267e-12, 3.51787039e-12, 6.62643335e-12, 1.24818752e-11,
#        2.35114728e-11, 4.42873643e-11, 8.34218534e-11, 1.57137498e-10,
#        2.95991905e-10, 5.57544883e-10, 1.05021891e-09, 1.97824390e-09,
#        3.72631731e-09, 7.01907421e-09, 1.32214728e-08, 2.49046151e-08,
#        4.69115556e-08, 8.83649089e-08]),
#                  'nn_hist_widths_l': array([6.25288958e-14, 1.17782498e-13, 2.21860894e-13, 4.17908072e-13,
#        7.87192159e-13, 1.48279379e-12, 2.79306318e-12, 5.26115091e-12,
#        9.91016213e-12, 1.86672679e-11, 3.51625821e-11, 6.62339658e-11,
#        1.24761549e-10, 2.35006979e-10, 4.42670682e-10, 8.33836227e-10,
#        1.57065485e-09, 2.95856258e-09, 5.57289370e-09, 1.04973762e-08,
#        1.97733730e-08, 3.72460961e-08]),
#                  'nn_hist_widths_r': array([8.58184684e-14, 1.61651880e-13, 3.04495416e-13, 5.73562514e-13,
#        1.08039051e-12, 2.03507659e-12, 3.83337017e-12, 7.22072424e-12,
#        1.36013106e-11, 2.56200964e-11, 4.82592713e-11, 9.09035324e-11,
#        1.71230356e-10, 3.22537904e-10, 6.07548229e-10, 1.14440767e-09,
#        2.15566246e-09, 4.06051164e-09, 7.64857905e-09, 1.44072390e-08,
#        2.71381825e-08, 5.11188128e-08]),
#                  'output_keys': ['hist'],
#                  'rel_counts': True,
#                  'return_hist': True,
#                  'which_histogram': 'dNdF'},
#         'label_shape': [[3], [22, 2]],
#         'output_keys': ['ff_mean', 'ff_logvar', 'hist'],
#         'params_folder': '../models/parameters/Example_comb_128/Training_1',
#         'remove_exp': True,
#         'requires_tau': True,
#         'run_name': 'Training_1',
#         'summaries_folder': '../models/summaries/Example_comb_128/Training_1',
#         'summaries_folder_ff': '../models/summaries/Example_comb_128/Training_1/ff',
#         'summaries_folder_hist': '../models/summaries/Example_comb_128/Training_1/hist'},
#  'plot': {'colors': ['#37c837', 'deepskyblue', 'k'],
#           'colors_P': ['#37c837'],
#           'colors_PS': ['deepskyblue', 'k']},
#  'train': {'batch_size': 16,
#            'batch_size_val': 16,
#            'eval_frequency': 50,
#            'ff_loss': 'l2',
#            'ff_train_metrics': ['l2', 'l1', 'x-ent'],
#            'hist_loss': 'EMPL',
#            'hist_pinball_smoothing': 0.001,
#            'hist_train_metrics': ['l2', 'l1', 'x-ent'],
#            'num_steps': 2500,
#            'optimizer': 'Adam',
#            'optimizer_dict': {'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-08},
#            'prefetch_batch_buffer': 5,
#            'prefetch_batch_buffer_val': 5,
#            'scheduler': 'ExponentialDecay',
#            'scheduler_dict': {'decay_rate': 0.99985,
#                               'decay_steps': 1,
#                               'initial_learning_rate': 0.0005,
#                               'staircase': False}},
#  'tt': {'add_two_temps_PS': ['iso_PS'],
#         'data_name': 'Example',
#         'filename_base': 'Maps',
#         'n_chunk': 100,
#         'n_sim_per_chunk': 50,
#         'poisson_A_is_log': False,
#         'priors': {'bub': array([0., 2.]),
#                    'gce_12_PS': {'enforce_upper_flux': True,
#                                  'flux_lims': [0, 1.4e-08],
#                                  'flux_log': False,
#                                  'mean_exp': [-12, -9],
#                                  'skew_std': 3.0,
#                                  'var_exp': 0.25},
#                    'iso_PS': {'enforce_upper_flux': True,
#                               'flux_lims': [0, 1.4e-08],
#                               'flux_log': False,
#                               'mean_exp': [-12, -9],
#                               'skew_std': 3.0,
#                               'var_exp': 0.25}}}}

# %% [markdown]
# The parameters are stored in gce.p and can also be accessed group-wise. For example, the Poissonian (P) and point-source (PS) templates used in this analysis can be viewed with

# %%
gce.p.mod
# Out:
# {'models_P': ['bub'],
#  'models_PS': ['gce_12_PS', 'iso_PS'],
#  'model_names_P': ['$\\it{Fermi}$ bubbles'],
#  'model_names_PS': ['GCE', 'isotropic PS'],
#  'models': ['bub', 'gce_12_PS', 'iso_PS'],
#  'model_names': ['$\\it{Fermi}$ bubbles', 'GCE', 'isotropic PS'],
#  'n_models_P': 1,
#  'n_models_PS': 2,
#  'n_models': 3}

# %% [markdown]
# and the data-related settings (such as the exposure map, the mask for the region of interest, as well as whether the *Fermi* point-spread function at 2 GeV shall be applied) are stored in

# %%
gce.p.data
# Out:
# {'outer_rad': 25.0,
#  'inner_band': 2.0,
#  'leakage_delta': 0.75,
#  'mask_type': '3FGL',
#  'nside': 128,
#  'exposure': 'Fermi',
#  'psf': True,
#  'npix': 196608}

# %% [markdown]
# Now, let's generate some simulated Monte Carlo photon-count maps for each of the templates. The relevant parameters are stored in the field "tt" (training and testing data) - most importantly the priors, as well as the number of maps given by "n_chunk" (each chunk will be saved in a single file) times the number of simulations per chunk.

# %%
gce.p.tt
# Out:
# {'data_name': 'Example',
#  'filename_base': 'Maps',
#  'poisson_A_is_log': False,
#  'n_chunk': 100,
#  'n_sim_per_chunk': 50,
#  'add_two_temps_PS': ['iso_PS'],
#  'priors': {'bub': array([0., 2.]),
#   'gce_12_PS': {'mean_exp': [-12, -9],
#    'var_exp': 0.25,
#    'skew_std': 3.0,
#    'flux_lims': [0, 1.4e-08],
#    'flux_log': False,
#    'enforce_upper_flux': True},
#   'iso_PS': {'mean_exp': [-12, -9],
#    'var_exp': 0.25,
#    'skew_std': 3.0,
#    'flux_lims': [0, 1.4e-08],
#    'flux_log': False,
#    'enforce_upper_flux': True}}}

# %% [markdown]
# To **generate** the template maps, we can simply run

# %%
# Ray settings (for parallelized data generation)
# ray_settings = {"num_cpus": 4, "object_store_memory": 2000000000}
ray_settings = {"num_cpus": 4}  # select the number of CPUs here
gce.generate_template_maps(ray_settings, n_example_plots=5, job_id=0)
# Out:
# Template maps exist already!

# %% [markdown]
# Some example maps (whose number is determined by ```n_example_plots``` above) for each template can be viewed in the folder ```GCE_NN/data/Template_maps/Example_128```.

# %% [markdown]
# The next step is to **combine** (i.e. sum up) the individual template maps to obtain the final training, validation, and testing maps. Internally, this is done in two steps: 1) the filenames of the template maps for each of these three subsets are stored in a file, and 2) the template maps are combined and saved.

# %%
gce.combine_template_maps(save_filenames=True, do_combine=True)
# Out:
# Combined maps exist already!

# %% [markdown]
# NOTE: if data has already been generated, the corresponding parameters can be directly loaded from the template maps / combined maps folders, e.g.
#
# ```
# gce.load_params("../data/Template_maps/Test_128")
# gce.load_params("../data/Combined_maps/Test_comb_128")
# ```

# %% [markdown]
# Next, we need to build the **data processing pipeline** that will feed the combined photon-count maps to the neural network.

# %%
gce.build_pipeline()
# Out:
# 2021-11-18 14:29:56.846920: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-11-18 14:29:56.864977: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3194070000 Hz
# Input pipeline successfully built.

# %% [markdown]
# We can use the method ```get_samples()``` to get photon-count maps and their associated labels from the datasets **train** (used for training), **val** (used as an independent validation dataset during training), and **test** (used for testing once the training is finished)

# %%
samples = gce.datasets["test"].get_samples(1)
data, labels = samples["data"], samples["label"]  # samples contains data and labels (flux fractions & SCD histograms)
print("Shapes:")
print("  Data", data.shape)  # n_samples x n_pix_in_ROI
print("  Flux fractions", labels[0].shape)  # n_samples x n_templates
print("  SCD histograms", labels[1].shape)  # n_samples x n_bins x n_PS_templates
# Out:
# Shapes:
#   Data (1, 7749)
#   Flux fractions (1, 3)
#   SCD histograms (1, 22, 2)

# %% [markdown]
# Let's take a look at a combined map. The maps are compressed and only contain the pixels that lie within the ROI - the method ```decompress()``` returns the full-sky map that can be fed to the healpy functions.

# %% [markdown]
# We will plot
# 1. the **photon-count map**,
# 2. the rescaled version in **'flux' space** as shown to the neural network (divided by exposure correction), and
# 3. the *Fermi* **exposure correction**.

# %%
# NOTE: the maps are stored in NEST format
map_to_plot = 0
r = gce.p.data["outer_rad"] + 1
hp.cartview(gce.decompress(data[map_to_plot] * gce.template_dict["rescale_compressed"]), nest=True,
            title="Simulated data: Count space", lonra=[-r, r], latra=[-r, r])
hp.cartview(gce.decompress(data[map_to_plot]), nest=True,
            title="Simulated data: Flux space", lonra=[-r, r], latra=[-r, r])
hp.cartview(gce.decompress(gce.template_dict["rescale_compressed"], fill_value=np.nan), nest=True,
            title="Fermi exposure correction", lonra=[-r, r], latra=[-r, r])
plt.show()

# %% [markdown]
# Let's also plot the real *Fermi* map in our region of interest. Of course, it looks quite different from our simulated maps because we only included the *Fermi* bubbles, the GCE, and isotropic point sources in this example (so we are completely ignoring the diffuse Galactic foregrounds, which are responsible for the majority of photon counts).

# %%
fermi_counts = gce.datasets["test"].get_fermi_counts()
hp.cartview(gce.decompress(fermi_counts * gce.generators["test"].settings_dict["rescale_compressed"]), nest=True,
            title="Fermi data: Count space", max=100, lonra=[-r, r], latra=[-r, r])
# hp.cartview(gce.decompress(fermi_counts), nest=True, title="Fermi data: Flux space", max=100)
plt.show()

# %% [markdown]
# Now, it's time to **build** our neural network:

# %%
gce.build_nn()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# The resolution will be successively reduced from nside=128 to nside=1 during a forward pass.
# WARNING:tensorflow:From /home/flo/.pyenv/versions/3.8.0/envs/venv_gce_nn_38/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# The resolution will be successively reduced from nside=128 to nside=1 during a forward pass.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 7749)]       0
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 7749, 1)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) (None, 1, 1)         0           tf.expand_dims[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv (TFOpLambda)    (None, 7749, 1)      0           tf.expand_dims[0][0]
#                                                                  tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# chebyshev (Chebyshev)           (None, 7749, 32)     256         tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes (HealpyP (None, 2140, 32)     0           chebyshev[0][0]
# __________________________________________________________________________________________________
# chebyshev_1 (Chebyshev)         (None, 2140, 64)     10432       healpy_pool_with_holes[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_1 (Healp (None, 589, 64)      0           chebyshev_1[0][0]
# __________________________________________________________________________________________________
# chebyshev_2 (Chebyshev)         (None, 589, 128)     41344       healpy_pool_with_holes_1[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_2 (Healp (None, 163, 128)     0           chebyshev_2[0][0]
# __________________________________________________________________________________________________
# chebyshev_3 (Chebyshev)         (None, 163, 256)     164608      healpy_pool_with_holes_2[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_3 (Healp (None, 50, 256)      0           chebyshev_3[0][0]
# __________________________________________________________________________________________________
# chebyshev_4 (Chebyshev)         (None, 50, 256)      328448      healpy_pool_with_holes_3[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_4 (Healp (None, 14, 256)      0           chebyshev_4[0][0]
# __________________________________________________________________________________________________
# chebyshev_5 (Chebyshev)         (None, 14, 256)      328448      healpy_pool_with_holes_4[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_5 (Healp (None, 4, 256)       0           chebyshev_5[0][0]
# __________________________________________________________________________________________________
# chebyshev_6 (Chebyshev)         (None, 4, 256)       328448      healpy_pool_with_holes_5[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze (TFOpLambd (None, 1)            0           tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_6 (Healp (None, 1, 256)       0           chebyshev_6[0][0]
# __________________________________________________________________________________________________
# tf.math.log (TFOpLambda)        (None, 1)            0           tf.compat.v1.squeeze[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None, 256)          0           healpy_pool_with_holes_6[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_1 (TFOpLambda)  (None, 1)            0           tf.math.log[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 257)          0           tf.math.reduce_mean[0][0]
#                                                                  tf.math.truediv_1[0][0]
# __________________________________________________________________________________________________
# fully_connected_block_1 (FullyC (None, 2048)         528384      tf.concat[0][0]
# __________________________________________________________________________________________________
# fully_connected_block_3 (FullyC (None, 512)          1049088     fully_connected_block_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 6)            3072        fully_connected_block_3[0][0]
# __________________________________________________________________________________________________
# final_layer (FinalLayer)        {'ff_mean': (None, 3 0           dense[0][0]
# __________________________________________________________________________________________________
# poisson_residual_layer (Poisson (None, 7749)         0           tf.math.truediv[0][0]
#                                                                  final_layer[0][1]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 7749, 1)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_2 (TFOpLambda)   (None, 7749, 1)      0           poisson_residual_layer[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 7749, 2)      0           tf.expand_dims_1[0][0]
#                                                                  tf.expand_dims_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 7749, 1)      0           tf.concat_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_1 (TFOpLambd (None, 1, 1)         0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_2 (TFOpLambda)  (None, 7749, 1)      0           tf.__operators__.getitem[0][0]
#                                                                  tf.math.reduce_sum_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 7749, 1)      0           tf.concat_1[0][0]
# __________________________________________________________________________________________________
# tf.concat_2 (TFOpLambda)        (None, 7749, 2)      0           tf.math.truediv_2[0][0]
#                                                                  tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# chebyshev_7 (Chebyshev)         (None, 7749, 32)     416         tf.concat_2[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_7 (Healp (None, 2140, 32)     0           chebyshev_7[0][0]
# __________________________________________________________________________________________________
# chebyshev_8 (Chebyshev)         (None, 2140, 64)     10432       healpy_pool_with_holes_7[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_8 (Healp (None, 589, 64)      0           chebyshev_8[0][0]
# __________________________________________________________________________________________________
# chebyshev_9 (Chebyshev)         (None, 589, 128)     41344       healpy_pool_with_holes_8[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_9 (Healp (None, 163, 128)     0           chebyshev_9[0][0]
# __________________________________________________________________________________________________
# chebyshev_10 (Chebyshev)        (None, 163, 256)     164608      healpy_pool_with_holes_9[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_10 (Heal (None, 50, 256)      0           chebyshev_10[0][0]
# __________________________________________________________________________________________________
# chebyshev_11 (Chebyshev)        (None, 50, 256)      328448      healpy_pool_with_holes_10[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_11 (Heal (None, 14, 256)      0           chebyshev_11[0][0]
# __________________________________________________________________________________________________
# chebyshev_12 (Chebyshev)        (None, 14, 256)      328448      healpy_pool_with_holes_11[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_12 (Heal (None, 4, 256)       0           chebyshev_12[0][0]
# __________________________________________________________________________________________________
# chebyshev_13 (Chebyshev)        (None, 4, 256)       328448      healpy_pool_with_holes_12[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze_1 (TFOpLam (None, 1)            0           tf.math.reduce_sum_1[0][0]
# __________________________________________________________________________________________________
# healpy_pool_with_holes_13 (Heal (None, 1, 256)       0           chebyshev_13[0][0]
# __________________________________________________________________________________________________
# tf.math.log_1 (TFOpLambda)      (None, 1)            0           tf.compat.v1.squeeze_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb (None, 256)          0           healpy_pool_with_holes_13[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_3 (TFOpLambda)  (None, 1)            0           tf.math.log_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 1)            0           input_2[0][0]
# __________________________________________________________________________________________________
# tf.concat_3 (TFOpLambda)        (None, 257)          0           tf.math.reduce_mean_1[0][0]
#                                                                  tf.math.truediv_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 1)            0           tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.concat_4 (TFOpLambda)        (None, 258)          0           tf.concat_3[0][0]
#                                                                  tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# fully_connected_block_5 (FullyC (None, 2048)         530432      tf.concat_4[0][0]
# __________________________________________________________________________________________________
# fully_connected_block_7 (FullyC (None, 512)          1049088     fully_connected_block_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 44)           22528       fully_connected_block_7[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 22, 2)        0           dense_1[0][0]
# __________________________________________________________________________________________________
# final_layer_1 (FinalLayer)      {'hist': (None, 22,  0           lambda[0][0]
# ==================================================================================================
# Total params: 5,586,720
# Trainable params: 5,581,728
# Non-trainable params: 4,992
# __________________________________________________________________________________________________

# %% [markdown]
# *NOTE*: Once the neural network has been trained, **loading** is as easy as ```gce.load_nn()```.

# %%
# gce.load_nn()

# %% [markdown]
# Let's **train** our neural network to predict
# 1. the **flux fractions** of the different templates (using a negative maximum log-likelihood loss function), and
# 2. the **SCD histograms** of the GCE and isotropic point source populations (using the *Earth Mover's pinball loss*, see [arXiv:2106.02051](https://arxiv.org/abs/2106.02051)).

# %%
gce.train_nn("flux_fractions")
# Out:
# Restored checkpoint from ../models/checkpoints/Example_comb_128/Training_1/ff/ckpt-2500.
# 19 tensor(s) will be trained.
# The total number of training steps (2500) has already been reached!

# %%
gce.train_nn("histograms")
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f077019ca60> and <tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f0770134b20>).
# Restored checkpoint from ../models/checkpoints/Example_comb_128/Training_1/hist/ckpt-2500.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 19 tensor(s) will be trained.
# The total number of training steps (2500) has already been reached!

# %% [markdown]
# Finally, let's **evaluate** the performance of our neural network on simulated test data.

# %%
n_samples = 20
test_samples = gce.datasets["test"].get_samples(n_samples)
test_data, test_ffs, test_hists = test_samples["data"], test_samples["label"][0], test_samples["label"][1]
tau = np.arange(5, 100, 5) * 0.01  # quantile levels for SCD histograms, from 5% to 95% in steps of 5%
pred = gce.predict(test_data, tau=tau, multiple_taus=True)  # get the NN predictions
# Out:
# 2021-11-18 14:30:01.559059: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-11-18 14:30:02.079397: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-11-18 14:30:02.079455: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.

# %%
# Make some plots (will be saved in the models folder)
gce.plot_nn_architecture()
gce.plot_flux_fractions(test_ffs, pred)
gce.plot_histograms(test_hists, pred, plot_inds=np.arange(9))
gce.plot_maps(test_data, decompress=True, plot_inds=np.arange(9))
plt.show()

# %% [markdown]
# Clearly, the training dataset is too small and the training was too short to obtain accurate and precise predictions. Still, the neural networks have already learned *something*, and the predictions are roughly in the right ballpark.
